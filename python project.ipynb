# %%
class FoodApp(object):

# main code

    def __init__(self,name):
        self.restro_name=name
        print('hi')
        
    
    def admin_register(self):
        pass
    
    def create_admin_id(self):
        self.create_admin_id = input("Enter mail id - ")
        self.create_password = input("create password - ")
        t = input("renter password - ")
        if t == self.create_password:
            print("your account has created")
        else:
            print("password not matching")
      
    def admin_login(self):
        pass
        p = input("Enter your user id - ")
        if p == self.create_admin_id:
            pass
        
        q = input("Enter your password - ")
        if q == self.create_password:
            print("login successfullly")
        else:
            print("you have entered worng user id or password")
            
            
            
    def add_food_item(self):
        pass
        self.addfooditem = input("Enter food name - ")
        self.Quantity = input("Enter food quantity in (250mm,4pieces) - ")
        self.price = int(input("Enter price - "))
        self.discount = int(input("Enter discount - "))
        self.stock = int(input("Enter stock - "))
        
        
    def edit_food_item(add_food_item):
        pass
        self.addfooditem = input("Enter food name - ")
        self.Quantity = input("Enter food quantity in (250mm,4pieces) - ")
        self.price = int(input("Enter price - "))
        self.discount = int(input("Enter discount - "))
        self.stock = int(input("Enter stock - "))
    

    def view_food_item(self):
        pass
        print(self.addfooditem)

    def delete_food_item(self):
        pass




    # user functions


    def user_register(self):
        pass
        
        self.username = input("Enter full name - ")
        self.phonenumber = input("Enter phone no - ")
        
        
        self.create_user_id = input("Enter mail id - ")
        self.create_password = input("create password - ")
        self.renter_password  = input("re-enter password -")
      
        if self.renter_password != self.create_password:
            print("password not matched")
            
        if len(self.phonenumber)!=10:
            print("wrong  mob no")
            
        else:
            print("account created")
           
               
            
        
    
    
    
        
    def user_login(self):
        pass
        b = input("Enter your user id - ")
        if b == self.create_user_id:
            pass
        
        
        c = input("Enter your password - ")
        if c == self.create_password:
            print("login successfullly")
        else:
            print("you have entered worng user id or password")
            

    def place_order(self):
        pass
    
    def ordered_history(self):
        pass

    def update_details(self):
        pass


# driver code

if __name__=="__main__":
    
    obj=FoodApp('monin resto')
    
    
    
            
#   1.Add new food items. Food Item will have the following details: 
#   2.FoodID //It should be generated automatically by the application. 
#   3.Name 4.Quantity. For eg, 100ml, 250gm, 4pieces etc 5.Price 6.Discount 7.Stock. Amount left in stock in the restaurant. 
#   8.Edit food items using FoodID. 9.View the list of all food items. 10.Remove a food item from the menu using FoodID.          

    

obj =  FoodApp(object)

# obj.create_user_id()
# obj.admin_login()
# obj.add_food_item()
# obj.edit_food_item()

obj.user_register()
# obj.user_login()
# Out:
# hi
# hi
# Enter full name - BANTI
# Enter phone no - 887
# Enter mail id - CHOUHAN
# create password - BANTI
# re-enter password -banti
# password not matched
# wrong  mob no
